# %%
import folium

m = folium.Map(location=[47.800965, 13.035831])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("index.html")

# %%
folium.Map(location=[47.800965, 13.035831], zoom_start=20)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[47.800965, 13.035831], zoom_start=12, tiles="OpenStreetMap")

tooltip = "Click me!"

folium.Marker(
    [47.82122849185476, 13.037804923371962], popup="<i>Asvö Sportplatz Itzling</i>", tooltip=tooltip
).add_to(m)
folium.Marker(
    [47.82104744799504, 13.054023401429816], popup="<b>PADELBASE Salzburg</b>", tooltip=tooltip
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# I downloaded the folium to my computer via anaconda
# Then imported the folium into Jupiter Notepad
# # import folium
#
# Using this command, the location was found by coordinates
# # m = folium.Map(location=[47.800965, 13.035831])
#
# I entered this command to make Notepad display the map on the screen
# # m
#
# Saved the file
# # m.save("index.html")
#
# Zoomed in on a part of the map using the
# # folium.Map(location=[47.800965, 13.035831], zoom_start=20)
#
# In the locations, I entered the coordinates of Salzburg, zoom, and which tile I used to make it easier for Jupiter to find further points
# # m = folium.Map(location=[47.800965, 13.035831], zoom_start=12, tiles="OpenStreetMap")
#
# Gave a tooltip
# Then specified the coordinates of the points, the name of the points, and a hint on what to do with them
# All of this is done so that a marker with a name and location is displayed on the map
# # tooltip = "Click me!"
#
# # folium.Marker(
#     [47.82122849185476, 13.037804923371962], popup="<i>Asvö Sportplatz Itzling</i>", tooltip=tooltip
# ).add_to(m)
# # folium.Marker(
#     [47.82104744799504, 13.054023401429816], popup="<b>PADELBASE Salzburg</b>", tooltip=tooltip
# ).add_to(m)
#
# And then I entered this command to make Notepad display the map on the screen
# # m
#
# I used this library for my assignment
# https://leafletjs.com/reference.html
#
# **Be a bit careful here. This may be the library behind folium, but you used the python API called folium
